# %%
# In churn modelling dataset. there isnt 100% corelation between the data and the decision of customer to stay or leave.
# So 85-86% is the best accuracy we can get

# %%
# For XGboost feature scaling is unnecessary as it is a gradient boosting algorithm
# So we can keep the interpretation of the problem. 
# High performance, fast execution speed, no feature scaling required (test both)

# %%
# Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')
dataset.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
dataset[['CreditScore', 'Age', 'Tenure', 'Balance', 
         'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']].describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary
# count  10000.00000    10000.000000     10000.000000
# mean       0.70550        0.515100    100090.239881
# std        0.45584        0.499797     57510.492818
# min        0.00000        0.000000        11.580000
# ...

# %%
# Separating Independent and Dependent Variables, discarding unnecessary columns
X = dataset.iloc[:, 3:13].values    # Independent Variables
y = dataset.iloc[:, 13].values      # Dependent Variables

# %%
# Encoding categorical data by one hot encoding
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# X[:, 1] is Geography
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])

# X[:, 2] is Gender
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])

# Only one hot encode Geography as Gender has can be 0/1
onehotencoder = OneHotEncoder(categorical_features = [1])
X = onehotencoder.fit_transform(X).toarray()

# Removing one dummy variable to avoid the dummy variable trap
X = X[:, 1:]

# %%
print(X[0:4, :])
# Out:
# [[0.0000000e+00 0.0000000e+00 6.1900000e+02 0.0000000e+00 4.2000000e+01
#   2.0000000e+00 0.0000000e+00 1.0000000e+00 1.0000000e+00 1.0000000e+00
#   1.0134888e+05]
#  [0.0000000e+00 1.0000000e+00 6.0800000e+02 0.0000000e+00 4.1000000e+01
#   1.0000000e+00 8.3807860e+04 1.0000000e+00 0.0000000e+00 1.0000000e+00
#   1.1254258e+05]
#  [0.0000000e+00 0.0000000e+00 5.0200000e+02 0.0000000e+00 4.2000000e+01
#   8.0000000e+00 1.5966080e+05 3.0000000e+00 1.0000000e+00 0.0000000e+00
#   1.1393157e+05]
#  [0.0000000e+00 0.0000000e+00 6.9900000e+02 0.0000000e+00 3.9000000e+01
#   1.0000000e+00 0.0000000e+00 2.0000000e+00 0.0000000e+00 0.0000000e+00
#   9.3826630e+04]]

# %%
# Dividing the dataset into train test and validation set (70/20/10)
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.30, random_state = 0)

# Extracting test set from the validation set
X_test = X_val[2000:] 
X_val = X_val[:2000]

y_test = y_val[2000:] 
y_val = y_val[:2000]

print(f'No. of records in Training set : {len(X_train)}')
print(f'No. of records in Validation set : {len(X_val)}')
print(f'No. of records in Test set : {len(X_test)}')
# Out:
# No. of records in Training set : 7000
# No. of records in Validation set : 2000
# No. of records in Test set : 1000

# %%
# Feature Scaling for more accurate results in this case
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train) #training data needs to be fitted before it is transformed
X_val = sc_X.transform(X_val)
X_test = sc_X.transform(X_test)

# %%
# Fittiing Random Forest classifier to training data
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=100, 
                                    criterion = 'entropy', 
                                    random_state=0)
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
# Visualising tree plot for all trees
import os
from sklearn.tree import export_graphviz
import six
import pydot
from sklearn import tree
dotfile = six.StringIO()
i_tree = 0
col = ['Geo1','Geo2','CreditScore', 'Gender', 'Age', 'Tenure', 'Balance','NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']
for tree_in_forest in classifier.estimators_:
    export_graphviz(tree_in_forest,out_file='tree.dot',
                    feature_names=col,
                    filled=True,
                    rounded=True)
    
    (graph,) = pydot.graph_from_dot_file('tree.dot')
    name = 'tree' + str(i_tree)
    graph.write_png(name+  '.png')
    os.system('dot -Tpng tree.dot -o tree.png')
    i_tree +=1
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# ~/anaconda2/envs/py3_environment/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# ~/anaconda2/envs/py3_environment/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# ~/anaconda2/envs/py3_environment/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3377         # pre-parsed the string as part of our And pre-parsing
# ...

# %%
estimator = classifier.estimators_[5]
print(estimator)

export_graphviz(estimator, out_file='tree1.dot', 
                feature_names = col,
                rounded = True, proportion = False, 
                precision = 2, filled = True)

# Convert to png using system command (requires Graphviz)
from subprocess import call
call(['dot', '-Tpng', 'tree1.dot', '-o', 'tree_single.png', '-Gdpi=600'])

# Display in jupyter notebook
from IPython.display import Image
Image(filename = 'tree.png')
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=1537364731, splitter='best')

# %% [markdown]
# ##### Model performance for Random Forest

# %%
# Predicting Validation set results
y_pred_val = classifier.predict(X_val)

# %%
# Making Confusion Matrix
from sklearn.metrics import confusion_matrix
cm_val = confusion_matrix(y_val, y_pred_val)

# %%
cm_val
# Out:
# array([[1529,   66],
#        [ 196,  209]])

# %%
# Computing model accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_val, y_pred_val)
# Out:
# 0.87

# %%
# Computing F1 score
from sklearn.metrics import f1_score
f1_score(y_val, y_pred_val, average='weighted')
# Out:
# 0.8597357215588262

# %%
# K-fold cross validation on the entire dataset
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X = X, y = y, cv =10)
avg_accuracy = accuracies.mean()
print(avg_accuracy)
# Out:
# 0.8644981199981199

# %%
# Function for plotting CAP curve
from scipy import integrate

def capcurve(y_values, y_preds_proba):
    num_pos_obs = np.sum(y_values)
    num_count = len(y_values)
    rate_pos_obs = float(num_pos_obs) / float(num_count)
    ideal = pd.DataFrame({'x':[0,rate_pos_obs,1],'y':[0,1,1]})
    xx = np.arange(num_count) / float(num_count - 1)

    y_cap = np.c_[y_values,y_preds_proba]
    y_cap_df_s = pd.DataFrame(data=y_cap)
    y_cap_df_s = y_cap_df_s.sort_values([1], ascending=False).reset_index(level = y_cap_df_s.index.names, drop=True)

    yy = np.cumsum(y_cap_df_s[0]) / float(num_pos_obs)
    yy = np.append([0], yy[0:num_count-1]) #add the first curve point (0,0) : for xx=0 we have yy=0

    percent = 0.5
    row_index = np.trunc(num_count * percent)
    
    row_index = int(row_index)
    
    val_y1 = yy[row_index]
    val_y2 = yy[row_index+1]
    
    if val_y1 == val_y2:
        val = val_y1*1.0
    else:
        val_x1 = xx[row_index]
        val_x2 = xx[row_index+1]
        val = val_y1 + ((val_x2 - percent)/(val_x2 - val_x1))*(val_y2 - val_y1)

    sigma_ideal = 1 * xx[num_pos_obs - 1 ] / 2 + (xx[num_count - 1] - xx[num_pos_obs]) * 1
    sigma_model = integrate.simps(yy,xx)
    sigma_random = integrate.simps(xx,xx)

    ar_value = (sigma_model - sigma_random) / (sigma_ideal - sigma_random)
    
    fig, ax = plt.subplots(nrows = 1, ncols = 1)
    ax.plot(ideal['x'],ideal['y'], color='grey', label='Perfect Model')
    ax.plot(xx,yy, color='red', label='User Model')
    ax.plot(xx,xx, color='blue', label='Random Model')
    ax.plot([percent, percent], [0.0, val], color='green', linestyle='--', linewidth=1)
    ax.plot([0, percent], [val, val], color='green', linestyle='--', linewidth=1, label=str(val*100)+'% of positive obs at '+str(percent*100)+'%')

    plt.xlim(0, 1.02)
    plt.ylim(0, 1.25)
    plt.title("CAP Curve - a_r value ="+str(ar_value))
    plt.xlabel('% of the data')
    plt.ylabel('% of positive obs')
    plt.legend()
    
    fig.set_size_inches(11,8)
    
    plt.show()

# %%
# Plotting the CAP curve for validation set
y_pred_proba = classifier.predict_proba(X=X_val)
capcurve(y_values=y_val, y_preds_proba=y_pred_proba[:,1])

# %%
# Predicting Test set results
y_pred_test = classifier.predict(X_test)

# %%
# Making Confusion Matrix
from sklearn.metrics import confusion_matrix
cm_test = confusion_matrix(y_test, y_pred_test)

# %%
cm_test
# Out:
# array([[757,  27],
#        [101, 115]])

# %%
# Plotting the CAP curve for test set
y_pred_prob_test = classifier.predict_proba(X=X_test)
capcurve(y_values=y_test, y_preds_proba=y_pred_prob_test[:,1])
